# %% [markdown]
# # Network results

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
aTest = np.load('classic_10eps_2nets_test.npy')
aTrain = np.load('classic_10eps_2nets_train.npy')

# %%
n_epochs = 10

# %%
plt.plot(range(n_epochs), aTest, 'r')
plt.plot(range(n_epochs), aTrain, 'b')
