# %% [markdown]
# # Network results

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Classic, 50 epochs, 20 Networks

# %%
aTest0 = np.load('classic_50eps_20nets_test.npy')
aTrain0 = np.load('classic_50eps_20nets_train.npy')

# %%
n_epochs0 = 50

# %%
plt.plot(range(n_epochs0), aTest0, 'r')
plt.plot(range(n_epochs0), aTrain0, 'b')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.legend(['Test', 'Train'])
plt.title("Average Epoch accuracy for 20 Networks")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
#plt.figure(figsize=(5,10)), only really shows up when saving
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ## Bini 1 step, 50 epochs, 20 Nets

# %%
aTest1 = np.load('bini_50eps_20nets_1step_test.npy')
aTrain1 = np.load('bini_50eps_20nets_1step_train.npy')

# %%
n_epochs1 = 50

# %%
plt.plot(range(n_epochs1), aTest1, 'r')
plt.plot(range(n_epochs1), aTrain1, 'b')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("Average Epoch accuracy for 20 Networks with 1 step of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['Test', 'Train'])

# %%
plt.plot(range(n_epochs1), aTest1, 'r')
plt.plot(range(n_epochs1), aTrain1, 'b')
plt.plot(range(n_epochs0), aTest0, 'g') # 
plt.plot(range(n_epochs0), aTrain0, 'y') #
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("1 Step Bini vs Classical")
#plt.title("Average Epoch accuracy for 20 Networks with 1 step of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['BTest', 'BTrain', 'CTest', 'CTrain'])

# %% [markdown]
# ##

# %% [markdown]
# ## Bini 2 steps, 50 epochs, 20 Nets

# %%
aTest1 = np.load('bini_2step_50eps_20nets_test.npy')
aTrain1 = np.load('bini_2step_50eps_20nets_train.npy')

# %%
n_epochs1 = 50

# %%
plt.plot(range(n_epochs1), aTest1, 'r')
plt.plot(range(n_epochs1), aTrain1, 'b')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("Average Epoch accuracy for 20 Networks with 2 steps of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['Test', 'Train'])

# %%
plt.plot(range(n_epochs1), aTest1, 'r')
plt.plot(range(n_epochs1), aTrain1, 'b')
plt.plot(range(n_epochs0), aTest0, 'g') # 
plt.plot(range(n_epochs0), aTrain0, 'y') #
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("2 Steps Bini vs Classical")
#plt.title("Average Epoch accuracy for 20 Networks with 1 step of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['BTest', 'BTrain', 'CTest', 'CTrain'])

# %% [markdown]
# ## Bini 2 Steps, 50 epochs 100 networks

# %%
aTest1 = np.load('bini_2step_100eps_20nets_test.npy')
aTrain1 = np.load('bini_2step_100eps_20nets_train.npy')
n_epochs1 = 50

# %%
plt.plot(range(n_epochs1), aTest1, 'r')
plt.plot(range(n_epochs1), aTrain1, 'b')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("Average Epoch accuracy for 100 Networks with 2 steps of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['Test', 'Train'])

# %%
plt.plot(range(n_epochs1), aTest1, 'r')
plt.plot(range(n_epochs1), aTrain1, 'b')
plt.plot(range(n_epochs0), aTest0, 'g') # 
plt.plot(range(n_epochs0), aTrain0, 'y') #
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("2 Steps Bini 100 networks vs Classical")
#plt.title("Average Epoch accuracy for 20 Networks with 1 step of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['BTest', 'BTrain', 'CTest', 'CTrain'])

# %% [markdown]
# ## Strassen 1 Step, 50 epochs, 20 Nets

# %%
aTest2 = np.load('strass_1step_50eps_20nets_test.npy')
aTrain2 = np.load('strass_1step_50eps_20nets_train.npy')

# %%
n_epochs2 = 50

# %%
plt.plot(range(n_epochs1), aTest2, 'r')
plt.plot(range(n_epochs1), aTrain2, 'b')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.legend(['Test', 'Train'])
plt.title("Average Epoch accuracy for 20 Networks with 1 step of Strassen")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(range(n_epochs1), aTest2, 'r')
plt.plot(range(n_epochs1), aTrain2, 'b')
plt.plot(range(n_epochs0), aTest0, 'g') 
plt.plot(range(n_epochs0), aTrain0, 'y')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("1 Step Strassen vs Classical")
#plt.title("Average Epoch accuracy for 20 Networks with 1 step of Bini")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['STest', 'STrain', 'CTest', 'CTrain'])

# %% [markdown]
# ## Strassen 2 Step

# %%
aTest3 = np.load('strass_2step_50eps_20nets_test.npy')
aTrain3 = np.load('strass_2step_50eps_20nets_train.npy')

# %%
plt.plot(range(n_epochs1), aTest3, 'r')
plt.plot(range(n_epochs1), aTrain3, 'b')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.legend(['Test', 'Train'])
plt.title("Average Epoch accuracy for 20 Networks with 2 steps of Strassen")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(range(n_epochs1), aTest3, 'r')
plt.plot(range(n_epochs1), aTrain3, 'b')
plt.plot(range(n_epochs0), aTest0, 'g') 
plt.plot(range(n_epochs0), aTrain0, 'y')
plt.yticks(np.arange(0.88, 1.0, 0.01))
plt.grid(b=True)
plt.title("2 Step Strassen vs Classical")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(['STest', 'STrain', 'CTest', 'CTrain'])
